# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# SAMUEL OJEDEJI
# Child Development Consultant

# %% [markdown]
# I am interested in data science because it is a skill that can afford me the opportunity to work from almost anywhere and still earn income.

# %% [markdown]
# ### Cell 5 performs a simple calculation.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ![ibm.png](attachment:ibm.png)
#
#  - Coursera
#  - EdX
#  - Udemy
#
#     1. Coursera
#     2. EdX
#     3. Udemy
#
# ***
